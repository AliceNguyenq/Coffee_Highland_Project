# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
working_path = "/content/drive/My Drive/BI9/"

# %% [markdown]
# #2017Segmentation3685case

# %%
data1 = pd.read_csv(working_path + '2017Segmentation3685case.csv')

# %%
data1
# Out:
#           ID                           Segmentation  Visit  Spending  \
# 0      92316  Seg.02 - Mass Asp (VND 25K - VND 59K)      4       120
# 1      96307  Seg.02 - Mass Asp (VND 25K - VND 59K)      4       120
# 2     105678  Seg.02 - Mass Asp (VND 25K - VND 59K)      4       120
# 3     106554  Seg.02 - Mass Asp (VND 25K - VND 59K)      4       120
# 4     106555  Seg.02 - Mass Asp (VND 25K - VND 59K)      4       120
# ...      ...                                    ...    ...       ...
# 4939  139086               Seg.01 - Mass (<VND 25K)     30       300
# 4940  139137               Seg.01 - Mass (<VND 25K)     30       300
# 4941  139183               Seg.01 - Mass (<VND 25K)     30       300
# 4942  139313               Seg.01 - Mass (<VND 25K)     30       300
# 4943  141432               Seg.01 - Mass (<VND 25K)     30       300
#
#              Brand  PPA
# 0     Indepentdent   30
# 1     Indepentdent   30
# 2     Indepentdent   30
# 3     Indepentdent   30
# ...

# %%
data1.describe()
# Out:
#                   ID        Visit     Spending          PPA
# count    4944.000000  4944.000000  4944.000000  4944.000000
# mean   124746.726739     9.286003   185.212783    26.125607
# std     14200.003243    11.251593   208.383542    17.454006
# min     89100.000000     1.000000     6.000000     5.000000
# 25%    113279.500000     3.000000    60.000000    12.000000
# 50%    127602.500000     4.000000   120.000000    20.000000
# 75%    136523.250000    10.000000   240.000000    35.000000
# max    142479.000000   120.000000  2500.000000   100.000000

# %%
data1.shape
# Out:
# (4944, 6)

# %% [markdown]
# #Brand_Image

# %%
Brand_Image = pd.read_csv(working_path + 'Brand_Image.csv')

# %%
Brand_Image.head()
# Out:
#        ID  Year    City         Awareness      Attribute        BrandImage
# 0  725118  2019  Hà Nội  Highlands Coffee  Popular brand  Highlands Coffee
# 1  725466  2019  Hà Nội  Highlands Coffee  Popular brand  Highlands Coffee
# 2  726561  2019  Hà Nội  Highlands Coffee  Popular brand  Highlands Coffee
# 3  726862  2019  Hà Nội  Highlands Coffee  Popular brand  Highlands Coffee
# 4  727219  2019  Hà Nội  Highlands Coffee  Popular brand  Highlands Coffee

# %%
Brand_Image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643072 entries, 0 to 643071
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          643072 non-null  int64
#  1   Year        643072 non-null  int64
#  2   City        643072 non-null  object
#  3   Awareness   642675 non-null  object
#  4   Attribute   643072 non-null  object
#  5   BrandImage  618568 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 29.4+ MB

# %%
# Tổng số dòng duplicated của Brand_Image:
Brand_Image.duplicated().sum()
# Out:
# np.int64(13977)

# %%
# Loại bỏ những dòng duplicated:
Brand_Image.drop_duplicates(inplace=True)

# %%
Brand_Image.shape
# Out:
# (629095, 6)

# %%
Brand_Image.isnull().sum()
# Out:
# ID                0
# Year              0
# City              0
# Awareness       394
# Attribute         0
# BrandImage    23988
# dtype: int64

# %% [markdown]
# Cột Awareness và BrandImage có null => Xử lý null

# %%
# Hiển thị những rows null của Awareness:
Brand_Image[Brand_Image['Awareness'].isnull()]
# Out:
#             ID  Year       City Awareness  \
# 40900    97503  2017     Hà Nội       NaN
# 40901    97503  2017     Hà Nội       NaN
# 40902    97503  2017     Hà Nội       NaN
# 40903    97503  2017     Hà Nội       NaN
# 40904    97503  2017     Hà Nội       NaN
# ...        ...   ...        ...       ...
# 577436  368429  2018  Hải Phòng       NaN
# 577437  368429  2018  Hải Phòng       NaN
# 577438  368429  2018  Hải Phòng       NaN
# 577439  368429  2018  Hải Phòng       NaN
# 577440  368429  2018  Hải Phòng       NaN
#
#                                       Attribute        BrandImage
# 40900   Good other beverages (other than coffee               NaN
# 40901                            Friendly staff  Highlands Coffee
# 40902                                Good music  Highlands Coffee
# 40903                                     Clean  Highlands Coffee
# 40904                     Recommended by others  Highlands Coffee
# ...

# %%
Brand_Image['Awareness'].value_counts()
# Out:
# Awareness
# Highlands Coffee                                 106427
# Trung Nguyên                                      81577
# Other 1                                           46571
# Street / Half street coffee (including carts)     39747
# Other                                             37812
# The Coffee House                                  37529
# Cộng Cà Phê                                       35825
# Indepedent Cafe                                   33554
# Milano                                            30133
# Starbucks                                         23643
# Phúc Long                                         21931
# Street                                            20358
# Aha Cafe                                          19114
# Other 2                                           18711
# Urban Station                                     13740
# Passio                                             9295
# Viva Star                                          7028
# ...

# %% [markdown]
# #BrandHealth

# %%
# Đọc file Brandhealth
Brandhealth = pd.read_csv(working_path + 'Brandhealth.csv')
# Out:
# <ipython-input-18-4160667627>:2: DtypeWarning: Columns (4,7,8,10,11,12,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   Brandhealth = pd.read_csv(working_path + 'Brandhealth.csv')

# %%
Brandhealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74419 entries, 0 to 74418
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                74419 non-null  int64
#  1   Year              74419 non-null  int64
#  2   City              74419 non-null  object
#  3   Brand             74419 non-null  object
#  4   Spontaneous       30993 non-null  object
#  5   Awareness         74305 non-null  object
#  6   Trial             47330 non-null  object
#  7   P3M               28849 non-null  object
#  8   P1M               19399 non-null  object
#  9   Comprehension     26346 non-null  object
#  10  Brand_Likability  10331 non-null  object
#  11  Weekly            13382 non-null  object
#  12  Daily             7621 non-null   object
#  13  Fre#visit         19332 non-null  float64
#  14  PPA               14073 non-null  float64
#  15  Spending          14073 non-null  float64
# ...

# %%
# Sum duplicated:
Brandhealth.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Count giá trị null:
Brandhealth.isnull().sum()
# Out:
# ID                      0
# Year                    0
# City                    0
# Brand                   0
# Spontaneous         43426
# Awareness             114
# Trial               27089
# P3M                 45570
# P1M                 55020
# Comprehension       48073
# Brand_Likability    64088
# Weekly              61037
# Daily               66798
# Fre#visit           55087
# PPA                 60346
# Spending            60346
# Segmentation        60346
# NPS#P3M             52814
# NPS#P3M#Group       52814
# Spending_use        60346
# dtype: int64

# %%
# Value count của spateneous:
Brandhealth['Spontaneous'].value_counts()
# Out:
# Spontaneous
# Highlands Coffee                                 4063
# Street / Half street coffee (including carts)    3814
# Trung Nguyên                                     3389
# Other                                            3367
# Other 1                                          3024
# Indepedent Cafe                                  2391
# Street                                           1565
# Other 2                                          1506
# Milano                                           1357
# Cộng Cà Phê                                      1284
# The Coffee House                                 1020
# Aha Cafe                                          763
# Starbucks                                         612
# Phúc Long                                         592
# Other 3                                           353
# Other Branded Cafe Chain                          327
# Urban Station                                     326
# ...

# %% [markdown]
# #Companion

# %%
# Đọc file companion
Companion = pd.read_csv(working_path + 'Companion.csv')

# %%
Companion
# Out:
#            ID       City Companion#group  Year
# 0      725466     Hà Nội         Friends  2019
# 1      726862     Hà Nội         Friends  2019
# 2      727015     Hà Nội         Friends  2019
# 3      727219     Hà Nội         Friends  2019
# 4      727611     Hà Nội         Friends  2019
# ...       ...        ...             ...   ...
# 20734  459898    Đà Nẵng          Others  2018
# 20735  118401     Hà Nội          Others  2017
# 20736  125797  Hải Phòng          Others  2017
# 20737  132471    Cần Thơ          Others  2017
# 20738  133932  Hải Phòng          Others  2017
#
# [20739 rows x 4 columns]

# %%
Companion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20739 entries, 0 to 20738
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               20739 non-null  int64
#  1   City             20739 non-null  object
#  2   Companion#group  20739 non-null  object
#  3   Year             20739 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 648.2+ KB

# %% [markdown]
# #Competitor database_xlnm#_FilterDatabase

# %%
# Đọc file Competitor database_xlnm#_FilterDatabase.csv
Competitor = pd.read_csv(working_path + 'Competitor database_xlnm#_FilterDatabase.csv')

# %%
Competitor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   No#         234 non-null    int64
#  1   Brand       234 non-null    object
#  2   City        234 non-null    object
#  3   Year        234 non-null    int64
#  4   StoreCount  234 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 9.3+ KB

# %% [markdown]
# #Dayofweek

# %%
# Đọc file:
Dayofweek = pd.read_csv(working_path + 'Dayofweek.csv')

# %%
Dayofweek.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39095 entries, 0 to 39094
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               39095 non-null  int64
#  1   City             39095 non-null  object
#  2   Dayofweek        39009 non-null  object
#  3   Visit#Dayofweek  39041 non-null  float64
#  4   Year             39095 non-null  int64
#  5   Weekday#end      39009 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.8+ MB

# %%
#Duplicated rows:
Dayofweek.duplicated().sum()
# Out:
# np.int64(37)

# %%
#Drop duplicates:
Dayofweek.drop_duplicates(inplace=True)

# %%
Dayofweek.head()
# Out:
#        ID     City Dayofweek  Visit#Dayofweek  Year Weekday#end
# 0  344625  Cần Thơ    Monday              4.0  2018    Weekdays
# 1  345343  Cần Thơ    Monday              4.0  2018    Weekdays
# 2  346249  Cần Thơ    Monday              4.0  2018    Weekdays
# 3  346725  Cần Thơ    Monday              4.0  2018    Weekdays
# 4  346833  Cần Thơ    Monday              4.0  2018    Weekdays

# %%
# Gía trị null:
Dayofweek.isnull().sum()
# Out:
# ID                  0
# City                0
# Dayofweek          49
# Visit#Dayofweek    54
# Year                0
# Weekday#end        49
# dtype: int64

# %% [markdown]
# #Daypart

# %%
# Đọc file:
Daypart = pd.read_csv(working_path + 'Daypart.csv')

# %%
Daypart
# Out:
#            ID     City             Daypart  Visit#Daypart  Year
# 0      729674   Hà Nội  5 PM - before 9 PM            2.0  2019
# 1      730472   Hà Nội  5 PM - before 9 PM            2.0  2019
# 2      732361   Hà Nội  5 PM - before 9 PM            2.0  2019
# 3      732732   Hà Nội  5 PM - before 9 PM            2.0  2019
# 4      733574   Hà Nội  5 PM - before 9 PM            2.0  2019
# ...       ...      ...                 ...            ...   ...
# 19184  139229  Đà Nẵng         Before 9 AM           30.0  2017
# 19185  139231  Đà Nẵng         Before 9 AM           30.0  2017
# 19186  139299  Đà Nẵng         Before 9 AM           30.0  2017
# 19187  139311  Đà Nẵng         Before 9 AM           30.0  2017
# 19188  139317  Đà Nẵng         Before 9 AM           30.0  2017
#
# [19189 rows x 5 columns]

# %%
# Duplicated rows:
Daypart.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count các value của 'Daypart'
Daypart['Daypart'].value_counts()
# Out:
# Daypart
# 5 PM - before 9 PM     6591
# Before 9 AM            5698
# 9 AM - before 11 AM    2370
# 2 PM - before 5 PM     2042
# 11 AM - before 2 PM    1644
# 9 PM or later           831
# Name: count, dtype: int64

# %%
Daypart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19189 entries, 0 to 19188
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             19189 non-null  int64
#  1   City           19189 non-null  object
#  2   Daypart        19176 non-null  object
#  3   Visit#Daypart  18342 non-null  float64
#  4   Year           19189 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 749.7+ KB

# %% [markdown]
# #NeedstateDayDaypart

# %%
# Read NeedstateDayDaypart.csv
NeedstateDayDaypart = pd.read_csv(working_path + 'NeedstateDayDaypart.csv')

# %%
NeedstateDayDaypart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75251 entries, 0 to 75250
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              75251 non-null  int64
#  1   City            75251 non-null  object
#  2   Year            75251 non-null  int64
#  3   Needstates      75251 non-null  object
#  4   Day#Daypart     63344 non-null  object
#  5   NeedstateGroup  63344 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.4+ MB

# %%
#Duplicated rows:
NeedstateDayDaypart.duplicated().sum()
# Out:
# np.int64(6158)

# %%
# Show các duplicated rows:
NeedstateDayDaypart[NeedstateDayDaypart.duplicated()]
# Out:
#            ID         City  Year                               Needstates  \
# 36301  110402    Hải Phòng  2017               Working / Business meeting
# 36311  112590    Hải Phòng  2017               Working / Business meeting
# 36340  134366    Hải Phòng  2017               Working / Business meeting
# 36419  112172      Đà Nẵng  2017               Working / Business meeting
# 36430  125723      Đà Nẵng  2017               Working / Business meeting
# ...       ...          ...   ...                                      ...
# 64800  850174  Hồ Chí Minh  2019  Drinking other beverages (excluding tea
# 64801  851546  Hồ Chí Minh  2019  Drinking other beverages (excluding tea
# 64802  853481  Hồ Chí Minh  2019  Drinking other beverages (excluding tea
# 64803  854128  Hồ Chí Minh  2019  Drinking other beverages (excluding tea
# 64804  854586  Hồ Chí Minh  2019  Drinking other beverages (excluding tea
#
#       Day#Daypart              NeedstateGroup
# ...

# %%
# Drop duplicated:
NeedstateDayDaypart.drop_duplicates(inplace=True)

# %%
# Value count của Day#Daypart
NeedstateDayDaypart['Day#Daypart'].value_counts()
# Out:
# Day#Daypart
# Overall                31446
# Weekends                8785
# Weekdays                6697
# 5 PM - before 9 PM      5394
# Before 9 AM             4130
# 2 PM - before 5 PM      2102
# 9 AM - before 11 AM     2015
# 11 AM - before 2 PM     1785
# 9 PM or later            918
# Name: count, dtype: int64

# %% [markdown]
# # SA#var

# %%
# đọc file SA#var
SAvar = pd.read_csv(working_path + 'SA#var.csv')

# %%
SAvar.isnull().sum()
# Out:
# ID                     0
# City                   0
# Group_size            15
# Age                    9
# MPI#Mean            3717
# TOM                    0
# BUMO                   0
# BUMO_Previous       5665
# MostFavourite          0
# Gender                 0
# MPI#detail          3685
# Age#group              9
# Age#Group#2            9
# MPI                 3717
# MPI#2               3717
# Occupation             0
# Occupation#group    5132
# Year                5132
# Col                 5132
# MPI_Mean_Use        6974
# dtype: int64

# %%
#Duplicated rows:
SAvar.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Count value của Group_size
SAvar['Group_size'].value_counts()
# Out:
# Group_size
# 3.0     3457
# 4.0     3439
# 2.0     2680
# 5.0     1128
# 1.0      614
# 6.0      325
# 7.0       48
# 8.0       24
# 10.0      23
# 12.0       2
# 30.0       1
# 28.0       1
# 35.0       1
# 24.0       1
# 9.0        1
# 20.0       1
# Name: count, dtype: int64
